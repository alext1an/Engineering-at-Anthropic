# %% [markdown]
# ## Basic Multi-LLM Workflows
#
# This notebook demonstrates three simple multi-LLM workflows. They trade off cost or latency for potentially improved task performances:
#
# 1. **Prompt-Chaining**: Decomposes a task into sequential subtasks, where each step builds on previous results
# 2. **Parallelization**: Distributes independent subtasks across multiple LLMs for concurrent processing
# 3. **Routing**: Dynamically selects specialized LLM paths based on input characteristics
#
# Note: These are sample implementations meant to demonstrate core concepts - not production code.

# %%
from concurrent.futures import ThreadPoolExecutor

from util import extract_xml, llm_call

# %%
def chain(input: str, prompts: list[str]) -> str:
    """Chain multiple LLM calls sequentially, passing results between steps."""
    result = input
    for i, prompt in enumerate(prompts, 1):
        print(f"\nStep {i}:")
        result = llm_call(f"{prompt}\nInput: {result}")
        print(result)
    return result


def parallel(prompt: str, inputs: list[str], n_workers: int = 3) -> list[str]:
    """Process multiple inputs concurrently with the same prompt."""
    with ThreadPoolExecutor(max_workers=n_workers) as executor:
        futures = [executor.submit(llm_call, f"{prompt}\nInput: {x}") for x in inputs]
        return [f.result() for f in futures]


def route(input: str, routes: dict[str, str]) -> str:
    """Route input to specialized prompt using content classification."""
    # First determine appropriate route using LLM with chain-of-thought
    print(f"\nAvailable routes: {list(routes.keys())}")
    selector_prompt = f"""
    Analyze the input and select the most appropriate support team from these options: {list(routes.keys())}
    First explain your reasoning, then provide your selection in this XML format:

    <reasoning>
    Brief explanation of why this ticket should be routed to a specific team.
    Consider key terms, user intent, and urgency level.
    </reasoning>

    <selection>
    The chosen team name
    </selection>

    Input: {input}""".strip()

    route_response = llm_call(selector_prompt)
    reasoning = extract_xml(route_response, "reasoning")
    route_key = extract_xml(route_response, "selection").strip().lower()

    print("Routing Analysis:")
    print(reasoning)
    print(f"\nSelected route: {route_key}")

    # Process input with selected specialized prompt
    selected_prompt = routes[route_key]
    return llm_call(f"{selected_prompt}\nInput: {input}")

# %% [markdown]
# ## Example Usage
#
# Below are practical examples demonstrating each workflow:
# 1. Chain workflow for structured data extraction and formatting
# 2. Parallelization workflow for stakeholder impact analysis
# 3. Route workflow for customer support ticket handling

# %%
# Example 1: Chain workflow for structured data extraction and formatting
# Each step progressively transforms raw text into a formatted table

data_processing_steps = [
    """Extract only the numerical values and their associated metrics from the text.
    Format each as 'value: metric' on a new line.
    Example format:
    92: customer satisfaction
    45%: revenue growth""",
    """Convert all numerical values to percentages where possible.
    If not a percentage or points, convert to decimal (e.g., 92 points -> 92%).
    Keep one number per line.
    Example format:
    92%: customer satisfaction
    45%: revenue growth""",
    """Sort all lines in descending order by numerical value.
    Keep the format 'value: metric' on each line.
    Example:
    92%: customer satisfaction
    87%: employee satisfaction""",
    """Format the sorted data as a markdown table with columns:
    | Metric | Value |
    |:--|--:|
    | Customer Satisfaction | 92% |""",
]

report = """
Q3 Performance Summary:
Our customer satisfaction score rose to 92 points this quarter.
Revenue grew by 45% compared to last year.
Market share is now at 23% in our primary market.
Customer churn decreased to 5% from 8%.
New user acquisition cost is $43 per user.
Product adoption rate increased to 78%.
Employee satisfaction is at 87 points.
Operating margin improved to 34%.
"""

print("\nInput text:")
print(report)
formatted_result = chain(report, data_processing_steps)
# Out:
# Input text:
#
# Q3 Performance Summary:
# Our customer satisfaction score rose to 92 points this quarter.
# Revenue grew by 45% compared to last year.
# Market share is now at 23% in our primary market.
# Customer churn decreased to 5% from 8%.
# New user acquisition cost is $43 per user.
# Product adoption rate increased to 78%.
# Employee satisfaction is at 87 points.
# Operating margin improved to 34%.
#
#
# Step 1:
# 92: customer satisfaction
# 45%: revenue growth
# 23%: market share
# 5%: customer churn
# 8%: customer churn
# 43: new user acquisition cost
# 78%: product adoption rate
# 87: employee satisfaction
# 34%: operating margin
#
# Step 2:
# 92%: customer satisfaction
# 45%: revenue growth
# 23%: market share
# 5%: customer churn
# 8%: customer churn
# 43%: new user acquisition cost
# 78%: product adoption rate
# 87%: employee satisfaction
# 34%: operating margin
#
# Step 3:
# 92%: customer satisfaction
# 87%: employee satisfaction
# 78%: product adoption rate
# 45%: revenue growth
# 43%: new user acquisition cost
# 34%: operating margin
# 23%: market share
# 8%: customer churn
# 5%: customer churn
#
# Step 4:
# Here is the formatted data as a markdown table:
#
# | Metric | Value |
# |:--|--:|
# | Customer Satisfaction | 92% |
# | Employee Satisfaction | 87% |
# | Product Adoption Rate | 78% |
# | Revenue Growth | 45% |
# | New User Acquisition Cost | 43% |
# | Operating Margin | 34% |
# | Market Share | 23% |
# | Customer Churn | 8% |
# | Customer Churn | 5% |

# %%
# Example 2: Parallelization workflow for stakeholder impact analysis
# Process impact analysis for multiple stakeholder groups concurrently

stakeholders = [
    """Customers:
    - Price sensitive
    - Want better tech
    - Environmental concerns""",
    """Employees:
    - Job security worries
    - Need new skills
    - Want clear direction""",
    """Investors:
    - Expect growth
    - Want cost control
    - Risk concerns""",
    """Suppliers:
    - Capacity constraints
    - Price pressures
    - Tech transitions""",
]

impact_results = parallel(
    """Analyze how market changes will impact this stakeholder group.
    Provide specific impacts and recommended actions.
    Format with clear sections and priorities.""",
    stakeholders,
)

for result in impact_results:
    print(result)
    print("+" * 80)
# Out:
# Here is the analysis for the **Customers** stakeholder group, based on the three key traits provided (Price Sensitive, Tech Hungry, Environmentally Conscious).
#
# ### Analysis: Customer Stakeholder Impact
#
# **Market Change Drivers:** Inflation/Recession, AI & Rapid Tech Evolution, Stricter Environmental Regulations (e.g., Carbon Taxes, EU Digital Product Passport)
#
# ---
#
# #### Priority 1: Inflation & Economic Pressure (Direct Impact on Price Sensitivity)
#
# **Specific Impacts:**
#
# - **Reduced Basket Size:** Customers will buy only essentials, defer non-urgent upgrades, and actively seek discounts or generic alternatives.
# - **Price-Quality Reassessment:** Premium brands face a "value audit." If a cheaper product has 80% of the features of a premium one, the price-sensitive segment will switch.
# - **Subscription Fatigue:** "Tech for less" models (like monthly phone payments or SaaS tools) will see higher churn as customers cut non-core subscriptions.
#
# **Recommended Actions (for Customers / Internal Strategy):**
#
# 1.  **Tiered Product Offerings:** Immediately introduce a "Value" or "Lite" tier that removes non-essential features (e.g., slower chip, less storage) to hit a low price point.
# 2.  **Loyalty & Retention Programs:** Offer "price-lock" guarantees or volume discounts for long-term commitments to prevent churn.
# 3.  **Financing Flexibility:** Expand access to "Buy Now, Pay Later" (BNPL) options, focusing on zero-interest plans.
#
# ---
#
# #### Priority 2: Rapid Tech Evolution & Obsolescence (Conflict with "Want Better Tech")
#
# **Specific Impacts:**
#
# - **Feature Parity Panic:** Customers feel anxious that a new phone/software will be obsolete in 12 months. This slows purchasing as they wait for the "next big thing."
# - **Data & Privacy Demands:** "Better tech" now implies AI and personalization. Price-sensitive customers will trade data for lower prices, but demand transparency.
# - **"Good Enough" Threshold:** The gap between "last year's tech" and "this year's tech" is shrinking. Customers may refuse to pay a premium for marginal gains (e.g., a faster processor they don't need).
#
# **Recommended Actions (for Customers / Internal Strategy):**
#
# 1.  **Trade-In & Upgrade Programs:** Offer guaranteed buy-back values. This solves the "obsolescence anxiety" and makes the price-sensitive customer feel they are not losing money.
# 2.  **Refurbished/Recertified Tech:** Create a premium line of "Like New" certified pre-owned devices. This hits the "better tech" desire at a lower price point.
# 3.  **Software-First Focus:** Instead of selling new hardware, offer software/subscription upgrades that make existing hardware *feel* like better tech (e.g., improved AI camera processing via an app update).
#
# ---
#
# #### Priority 3: Environmental Regulation & Greenwashing Backlash (Impact on Environmental Concerns)
#
# **Specific Impacts:**
#
# - **Green Premium Rejection:** Customers *want* to be green, but they are *price sensitive*. They will not pay a 20% "eco-tax." If a sustainable product is too expensive, they will buy the non-green version and feel guilty (leading to brand resentment).
# - **Trust Deficit:** Customers are increasingly skeptical of "green" claims. A market change toward stricter regulation (EU Green Claims Directive) will expose brands that are actually performing poorly on sustainability.
# - **Repairability Rights Push:** "Want better tech" + "Environmental concerns" = **Repairability**. Customers will favor brands that make it easy to fix (battery swaps, modular parts) to avoid e-waste and cost of full replacement.
#
# **Recommended Actions (for Customers / Internal Strategy):**
#
# 1.  **"Green as the Default, Cheap as the Option":** Make the sustainable version the standard model (e.g., recycled packaging, energy-efficient chips) to avoid a "green premium." The price-sensitive customer gets sustainability without penalty.
# 2.  **Transparency & Certifications:** Publish clear, third-party-verified lifecycle assessments (carbon footprint per product). Use simple labels (A-G energy rating) rather than vague marketing.
# 3.  **Repair & Part Sales:** Launch a self-service repair portal with affordable parts. This directly addresses both the "price" (no full replacement cost) and the "environment" (less waste).
#
# ### Summary Priority Matrix
#
# | Priority | Focus Area | Key Customer Pain Point | Urgency |
# | :--- | :--- | :--- | :--- |
# | **1** | **Value Engineering** | Can't afford current premium tech. | **High** (Revenue Risk) |
# | **2** | **Obsolescence Management** | Afraid of buying "old tech" tomorrow. | **Medium** (Conversion) |
# | **3** | **Sustainability Execution** | Want to be green, but not at any cost. | **Medium-High** (Reputation) |
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Here is an analysis of how market changes will impact the **Employees** stakeholder group, structured with specific impacts and prioritized actions.
#
# ### Executive Summary
# Market changes—driven by automation, AI adoption, economic volatility, and shifting consumer demands—are creating a "perfect storm" of anxiety for employees. The primary risks are talent flight (due to insecurity) and skill obsolescence (due to lack of training). The recommended strategy is a **"Security through Adaptability"** approach: replacing the promise of lifetime employment with a promise of lifetime employability.
#
# ---
#
# ### 1. Impact: Job Security Worries
# **Market Change:** Rapid automation of routine tasks (e.g., data entry, basic analysis) and cost-cutting measures (e.g., offshoring, restructuring) due to economic pressure.
#
# - **Specific Impact:** Employees in mid-level, operational roles will experience heightened anxiety and "survivor syndrome." This leads to decreased productivity, increased presenteeism (being at work but not engaged), and a higher risk of top performers leaving proactively before they are laid off.
# - **Priority:** **High** (Directly impacts retention and morale).
#
# **Recommended Actions:**
# 1.  **Transparent Communication Cadence (Priority 1):** Hold monthly "State of the Business" briefings. Be honest about which roles are at risk and which are growing. Silence is the biggest driver of fear.
# 2.  **Internal Mobility First Policy (Priority 2):** Publicly commit to redeploying affected employees into growth areas (e.g., from sales support to customer success) before hiring externally. This builds trust.
# 3.  **Severance & Outplacement Support:** For roles that are definitively being eliminated, provide generous severance and career coaching to protect the employer brand and reduce guilt among remaining staff.
#
# ---
#
# ### 2. Impact: Need for New Skills
# **Market Change:** The rise of Generative AI, data analytics, and digital customer engagement requires a workforce that is technically literate and adaptable.
#
# - **Specific Impact:** A "skills gap" emerges. Employees feel overwhelmed and underqualified. Those who cannot or will not upskill become a liability, while those who do upskill may leave for higher pay if the current employer does not recognize the new value.
# - **Priority:** **High** (Directly impacts operational capability and future readiness).
#
# **Recommended Actions:**
# 1.  **Upskilling as a Core Benefit (Priority 1):** Launch a "Future Skills Fund." Offer paid time (e.g., 4 hours/week) for learning, subsidized certifications (e.g., AI prompt engineering, data visualization), and access to platforms like Coursera or Udemy.
# 2.  **Role Redesign (Priority 2):** Actively redesign job descriptions to integrate new tools. For example, change "Data Entry Clerk" to "Data Quality Analyst (AI-Assisted)." This makes the skill requirement explicit and the job more secure.
# 3.  **Mentorship & Reverse Mentoring:** Pair senior leaders (who need digital skills) with junior staff (who need business acumen). This creates a culture of mutual learning and breaks down hierarchy.
#
# ---
#
# ### 3. Impact: Want Clear Direction
# **Market Change:** Rapid pivots in strategy (e.g., moving from growth-at-all-costs to profitability) create confusion about priorities and performance metrics.
#
# - **Specific Impact:** Employees feel "directionless" and disempowered. They waste time on tasks that become irrelevant, leading to burnout and frustration. Decision-making slows down as people wait for clarity from above.
# - **Priority:** **Medium** (Critical for execution, but slightly less urgent than retention/skills).
#
# **Recommended Actions:**
# 1.  **The "North Star" Framework (Priority 1):** Define one clear, simple metric for the next 6 months (e.g., "Customer Retention Rate" or "Gross Margin"). Every team must explain how their work impacts that single metric.
# 2.  **Manager Enablement (Priority 2):** Train middle managers to translate high-level strategy into weekly team goals. Employees need direction from their direct boss, not just the CEO.
# 3.  **Quarterly "Reset" Meetings:** Instead of annual planning, hold quarterly 2-hour sessions where the entire team reviews what changed in the market and adjusts their top 3 priorities accordingly. This reduces the fear of being "left behind" by a sudden pivot.
#
# ### Summary of Priorities
#
# | Priority | Focus Area | Key Action |
# | :--- | :--- | :--- |
# | **1 (Urgent)** | **Job Security** | Launch transparent communication cadence & internal mobility policy. |
# | **2 (Strategic)** | **New Skills** | Fund upskilling programs & redesign roles to match new market needs. |
# | **3 (Operational)** | **Clear Direction** | Implement a "North Star" metric & empower managers to translate strategy. |
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Here is an analysis of how current market changes will impact **Investors**, structured with clear sections and prioritized actions.
#
# ### Executive Summary
# Investors are currently navigating a "trilemma": they demand **growth** (revenue expansion), **cost control** (margin protection), and **risk mitigation** (capital preservation). The current market environment—characterized by high interest rates, inflation volatility, geopolitical instability, and a shift from "growth at all costs" to "profitable growth"—creates tension between these three goals. The primary impact is a **flight to quality** and a **shortened time horizon** for returns.
#
# ---
#
# ### 1. Impact on Growth Expectations
#
# **Market Change:** Slowing global GDP, rising cost of capital, and market saturation in key tech/consumer sectors.
# - **Specific Impact:** Investors can no longer rely on "TAM (Total Addressable Market) expansion" alone. Growth must be **profitable** and **organic**. Companies that previously grew through cheap debt or aggressive customer acquisition (e.g., unprofitable SaaS, EV startups) are now being penalized.
# - **Investor Sentiment Shift:** From "What is your revenue growth rate?" to "What is your **Rule of 40** (Growth Rate + Profit Margin)?"
#
# **Recommended Actions (Priority: High)**
# - **Shift to "Efficiency Growth":** Demand that management focuses on **Net Revenue Retention (NRR)** and **unit economics** (CAC payback < 12 months) rather than just top-line bookings.
# - **Prioritize Market Share Gains:** In a slow market, recommend aggressive M&A of distressed competitors to consolidate market share without relying on organic demand.
# - **Set Realistic Guidance:** Advise portfolio companies to lower forward guidance to beatable numbers. Missing estimates in a high-interest environment triggers a 2x-3x more severe stock price drop than in a bull market.
#
# ---
#
# ### 2. Impact on Cost Control Demands
#
# **Market Change:** Persistent inflation in labor and raw materials, coupled with high interest rates (making debt expensive).
# - **Specific Impact:** Investors are now hyper-focused on **Operating Leverage**. They want to see that every dollar of revenue growth drops more to the bottom line. The "ZIRP era" (Zero Interest Rate Policy) tolerance for high burn rates is over.
# - **Risk:** Companies that cannot pass on cost increases to customers (low pricing power) will see margin compression, leading to dividend cuts or equity dilution.
#
# **Recommended Actions (Priority: High)**
# - **Demand a "Zero-Based Budgeting" Review:** Require management to justify every expense line item from zero, not just cut 10% across the board. This protects high-ROI spending (R&D, sales) while eliminating bloat.
# - **Push for Variable Cost Structures:** Recommend outsourcing non-core functions (IT, HR, logistics) to convert fixed costs into variable costs, protecting margins during revenue dips.
# - **Monitor Cash Conversion Cycle (CCC):** Aggressively manage inventory and receivables. In a high-rate environment, cash tied up in working capital is a direct drag on investor returns.
#
# ---
#
# ### 3. Impact on Risk Concerns
#
# **Market Change:** Geopolitical fragmentation (tariffs, sanctions), regulatory tightening (ESG, antitrust), and higher volatility in public markets.
# - **Specific Impact:** Investors are demanding a **higher risk premium**. The "risk-free rate" (10-year Treasury) is now ~4-5%, meaning any investment must offer a significantly higher return to justify the risk. This leads to **capital flight** from early-stage ventures and highly leveraged firms.
# - **Key Concern:** **Liquidity risk**. Investors fear being locked into illiquid private assets (VC, PE) while needing cash to cover margin calls or redemptions.
#
# **Recommended Actions (Priority: Medium - High)**
# - **Diversify by Geography & Currency:** Recommend shifting exposure to "friend-shoring" markets (e.g., Mexico, India, Vietnam) to mitigate tariff and supply chain disruption risks.
# - **Stress Test for "Higher for Longer":** Demand that portfolio companies model their cash runway assuming interest rates stay at current levels for 24+ months. Any company with debt maturing in <18 months is a red flag.
# - **Increase Hedging:** For public equity investors, recommend buying put options or increasing allocation to defensive sectors (Healthcare, Utilities, Consumer Staples) to offset volatility in growth holdings.
#
# ---
#
# ### Summary Table: Prioritized Action Plan for Investors
#
# | Priority | Investor Concern | Market Change | Specific Action |
# | :--- | :--- | :--- | :--- |
# | **1 (Critical)** | **Cost Control** | High inflation / Interest rates | **Enforce Zero-Based Budgeting** & demand **Operating Leverage** metrics. |
# | **2 (Critical)** | **Growth** | Slowing demand / High capital cost | **Shift focus to NRR & Unit Economics.** Stop funding unprofitable growth. |
# | **3 (High)** | **Risk** | Geopolitical instability / Volatility | **Stress test liquidity** & diversify supply chains (Friend-shoring). |
# | **4 (Medium)** | **Risk** | Regulatory tightening | **Increase hedging** (Options/Defensive sectors) to protect portfolio value. |
#
# **Final Recommendation for Investors:**
# The current market rewards **discipline** over **ambition**. The most successful investors will be those who force their portfolio companies to operate with the efficiency of a mature firm while retaining the agility of a startup. **Cash is a strategy, not a byproduct.**
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Here is a structured analysis of how market changes will impact **Suppliers**, focusing on the three specified pressure points.
#
# ### Executive Summary
# Suppliers are currently caught in a "triple squeeze": they must invest in new technology while facing margin erosion from buyers and physical limits on output. The market is shifting from a volume-driven model to a value-and-resilience model. Suppliers who fail to adapt risk being commoditized or disintermediated.
#
# ---
#
# ### 1. Capacity Constraints
#
# **Market Change:** Post-pandemic demand volatility, labor shortages, and raw material scarcity are creating structural capacity ceilings. Buyers are shifting from "just-in-time" to "just-in-case" inventory strategies, increasing order variance.
#
# **Specific Impacts on Suppliers:**
# - **Lost Revenue & Penalties:** Inability to fulfill surge orders leads to missed revenue and contractual penalties (e.g., chargebacks from retailers or OEMs).
# - **Strained Relationships:** Buyers will dual-source or vertical integrate if a supplier is perceived as unreliable, reducing the supplier’s long-term share of wallet.
# - **Operational Burnout:** Running at 100% capacity constantly increases maintenance costs, overtime wages, and employee turnover.
#
# **Recommended Actions (Priority: High)**
# - **Implement Dynamic Capacity Management:** Use predictive analytics to forecast demand spikes 4-6 weeks out. Do not rely solely on buyer forecasts (which are often inflated).
# - **Invest in Bottleneck De-bottlenecking:** Focus capital on the single slowest machine or process. A 10% improvement here yields more output than a 20% improvement elsewhere.
# - **Create a "Surge Pricing" Clause:** Renegotiate contracts to include premium pricing for orders exceeding 90% of agreed capacity. This compensates for the inefficiency of high utilization.
#
# ---
#
# ### 2. Price Pressures
#
# **Market Change:** Inflationary input costs (energy, logistics, labor) are colliding with buyer demands for deflationary pricing. Large retailers and OEMs are using their market power to squeeze supplier margins to maintain their own profitability.
#
# **Specific Impacts on Suppliers:**
# - **Margin Erosion:** Suppliers absorb cost increases because they lack the bargaining power to pass them through. This leads to negative operating margins on legacy contracts.
# - **Cash Flow Crunch:** Longer payment terms (Net 60/90) from buyers combined with immediate cash payments for raw materials create a liquidity gap.
# - **Commoditization:** If a supplier cannot differentiate, they are forced to compete solely on price, leading to a race to the bottom.
#
# **Recommended Actions (Priority: High)**
# - **Adopt Value-Based Pricing:** Stop selling "widgets." Sell "uptime," "quality yield," or "sustainability credits." Quantify the value you provide to the buyer’s end product and price accordingly.
# - **Implement Escalation Clauses:** Insert automatic price adjustment formulas tied to publicly indexed raw material costs (e.g., steel, copper, energy). This removes the need for annual renegotiation.
# - **Segment the Customer Base:** Fire the bottom 10% of customers who demand the lowest prices but also require the most service. Reallocate capacity to higher-margin, strategic accounts.
#
# ---
#
# ### 3. Tech Transitions
#
# **Market Change:** Rapid adoption of Industry 4.0 (IoT, AI), electrification (in automotive/energy), and digital supply chain platforms. Buyers are demanding real-time data integration and sustainable production methods.
#
# **Specific Impacts on Suppliers:**
# - **Obsolescence Risk:** Suppliers using legacy machinery or manual processes will be locked out of RFPs (Requests for Proposal) that require API integration or carbon footprint reporting.
# - **High Capital Expenditure:** The cost of upgrading to smart factories or new material chemistries (e.g., from steel to composites) is prohibitive for small-to-mid suppliers.
# - **Talent Gap:** Difficulty hiring data scientists, automation engineers, or sustainability managers to manage the transition.
#
# **Recommended Actions (Priority: Critical)**
# - **Adopt a "Lighthouse" Strategy:** Do not digitize the entire factory at once. Pick one high-impact line (e.g., the one with the most defects or downtime) and automate it fully. Prove ROI before scaling.
# - **Leverage "Tech-as-a-Service":** Avoid large upfront CAPEX. Use leasing models for robotics or cloud-based MES (Manufacturing Execution Systems) that charge per unit produced.
# - **Form a Supplier Consortium:** Partner with 2-3 non-competing suppliers to jointly purchase a shared ERP system or a renewable energy PPA (Power Purchase Agreement). This reduces individual cost and risk.
#
# ---
#
# ### Priority Ranking for Action
#
# | Priority | Focus Area | Rationale |
# | :--- | :--- | :--- |
# | **1** | **Tech Transitions** | This is existential. Without digital integration, you will be removed from supply chains within 3-5 years. |
# | **2** | **Price Pressures** | This is immediate. Without margin protection, you will not have the cash flow to fund the tech transition. |
# | **3** | **Capacity Constraints** | This is operational. Manageable through pricing and process optimization, but not a survival threat if the other two are solved. |
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++

# %%
# Example 3: Route workflow for customer support ticket handling
# Route support tickets to appropriate teams based on content analysis

support_routes = {
    "billing": """You are a billing support specialist. Follow these guidelines:
    1. Always start with "Billing Support Response:"
    2. First acknowledge the specific billing issue
    3. Explain any charges or discrepancies clearly
    4. List concrete next steps with timeline
    5. End with payment options if relevant

    Keep responses professional but friendly.

    Input: """,
    "technical": """You are a technical support engineer. Follow these guidelines:
    1. Always start with "Technical Support Response:"
    2. List exact steps to resolve the issue
    3. Include system requirements if relevant
    4. Provide workarounds for common problems
    5. End with escalation path if needed

    Use clear, numbered steps and technical details.

    Input: """,
    "account": """You are an account security specialist. Follow these guidelines:
    1. Always start with "Account Support Response:"
    2. Prioritize account security and verification
    3. Provide clear steps for account recovery/changes
    4. Include security tips and warnings
    5. Set clear expectations for resolution time

    Maintain a serious, security-focused tone.

    Input: """,
    "product": """You are a product specialist. Follow these guidelines:
    1. Always start with "Product Support Response:"
    2. Focus on feature education and best practices
    3. Include specific examples of usage
    4. Link to relevant documentation sections
    5. Suggest related features that might help

    Be educational and encouraging in tone.

    Input: """,
}

# Test with different support tickets
tickets = [
    """Subject: Can't access my account
    Message: Hi, I've been trying to log in for the past hour but keep getting an 'invalid password' error.
    I'm sure I'm using the right password. Can you help me regain access? This is urgent as I need to
    submit a report by end of day.
    - John""",
    """Subject: Unexpected charge on my card
    Message: Hello, I just noticed a charge of $49.99 on my credit card from your company, but I thought
    I was on the $29.99 plan. Can you explain this charge and adjust it if it's a mistake?
    Thanks,
    Sarah""",
    """Subject: How to export data?
    Message: I need to export all my project data to Excel. I've looked through the docs but can't
    figure out how to do a bulk export. Is this possible? If so, could you walk me through the steps?
    Best regards,
    Mike""",
]

print("Processing support tickets...\n")
for i, ticket in enumerate(tickets, 1):
    print(f"\nTicket {i}:")
    print("-" * 40)
    print(ticket)
    print("\nResponse:")
    print("-" * 40)
    response = route(ticket, support_routes)
    print(response)
    print("+" * 80)
# Out:
# Processing support tickets...
#
#
# Ticket 1:
# ----------------------------------------
# Subject: Can't access my account
#     Message: Hi, I've been trying to log in for the past hour but keep getting an 'invalid password' error.
#     I'm sure I'm using the right password. Can you help me regain access? This is urgent as I need to
#     submit a report by end of day.
#     - John
#
# Response:
# ----------------------------------------
#
# Available routes: ['billing', 'technical', 'account', 'product']
# Routing Analysis:
#
# The user is unable to log in to their account due to an "invalid password" error, and they need urgent help to regain access. This is a classic account access issue, not a billing, technical product bug, or general product inquiry. The account team is responsible for handling password resets, account recovery, and access-related problems. The urgency (need to submit a report by end of day) further supports routing to the team that can directly resolve account access.
#
#
# Selected route: account
# Account Support Response:
#
# Hello John,
#
# Thank you for reaching out. I understand the urgency of your situation, but account security must come first. To protect your account from unauthorized access, we cannot simply reset your password without proper verification.
#
# **Immediate Steps to Regain Access:**
#
# 1. **Initiate a Password Reset**
#    Go to our login page and click **“Forgot Password”** (or the equivalent link). Enter the email address associated with your account. You will receive a password reset link within 5–10 minutes.
#    *If you do not see the email, check your spam/junk folder and ensure the email address is correct.*
#
# 2. **Verify Your Identity**
#    If you have two-factor authentication (2FA) enabled, you will need to use your backup codes or authenticator app to complete the reset. If you no longer have access to your 2FA method, please reply to this message with the following information for manual verification:
#    - Full name on the account
#    - Last four digits of the phone number on file (if any)
#    - Date of account creation (approximate)
#    - Any recent successful login locations or devices you recognize
#
# 3. **Check for Account Lockout**
#    Multiple failed login attempts may have temporarily locked your account. If you see a lockout message, wait 15 minutes before attempting the password reset above.
#
# **Security Tips & Warnings:**
#
# - **Do not** share your password or reset link with anyone, including support staff. We will never ask for your password.
# - **Beware of phishing** – only use the official password reset link from our login page. Do not click links in unsolicited emails.
# - **Enable 2FA** after regaining access to prevent future lockouts.
# - **Use a unique, strong password** – avoid reusing passwords from other sites.
#
# **Resolution Time Expectation:**
#
# - Password reset email: typically delivered within **5–10 minutes**.
# - Manual identity verification (if needed): **1–2 business hours** during business days.
# - Full account access restored immediately after successful password reset.
#
# If you do not receive the reset email within 15 minutes, or if you have additional verification issues, please reply with the requested information and we will prioritize your case.
#
# Stay safe,
# Account Security Specialist
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# Ticket 2:
# ----------------------------------------
# Subject: Unexpected charge on my card
#     Message: Hello, I just noticed a charge of $49.99 on my credit card from your company, but I thought
#     I was on the $29.99 plan. Can you explain this charge and adjust it if it's a mistake?
#     Thanks,
#     Sarah
#
# Response:
# ----------------------------------------
#
# Available routes: ['billing', 'technical', 'account', 'product']
# Routing Analysis:
#
# The user reports an unexpected charge on their credit card, specifically a $49.99 charge when they expected a $29.99 plan. They request an explanation and potential adjustment. This directly involves billing discrepancies, pricing plans, and payment issues. The intent is to resolve a billing error, not a technical problem, account access issue, or product feedback. Therefore, the billing team is the most appropriate.
#
#
# Selected route: billing
# Billing Support Response:
#
# Hi Sarah,
#
# Thank you for reaching out. I completely understand your concern about the $49.99 charge appearing on your card when you expected the $29.99 plan. Let me look into this for you.
#
# First, I’ll explain a couple of common reasons for this discrepancy:
# - It’s possible your account was upgraded or renewed at a different tier, or a promotional period ended.
# - Sometimes, a one-time add-on or pro-rated charge might also cause a higher amount.
#
# To clarify the situation and adjust it if it’s an error, here are the next steps:
#
# 1. **Account Review** – I’ll check your current plan and billing history within the next 1–2 business days to identify the exact cause.
# 2. **Correction** – If the charge is indeed a mistake, I’ll process a refund or adjustment. You can expect the corrected amount to appear on your card within 5–10 business days, depending on your bank.
# 3. **Plan Confirmation** – I’ll also ensure your account is set to the $29.99 plan going forward.
#
# Please reply with your account email or customer ID (if you have it handy), and I’ll get started right away. If you’d like a quicker resolution, feel free to call our billing team at [phone number] during business hours.
#
# As for payment options, any refund issued will be credited back to the same card used for the charge. If you’d like to discuss alternative payment methods or set up automatic billing for the correct amount, I’m happy to help with that as well.
#
# Looking forward to resolving this for you!
# Best regards,
# [Your Name]
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# Ticket 3:
# ----------------------------------------
# Subject: How to export data?
#     Message: I need to export all my project data to Excel. I've looked through the docs but can't
#     figure out how to do a bulk export. Is this possible? If so, could you walk me through the steps?
#     Best regards,
#     Mike
#
# Response:
# ----------------------------------------
#
# Available routes: ['billing', 'technical', 'account', 'product']
# Routing Analysis:
#
# The user is asking how to perform a bulk export of project data to Excel, indicating they have already consulted documentation but need guidance. This is a feature usage question related to product functionality, not a billing issue, account management problem, or technical bug. The intent is to understand product capabilities and steps, which falls under product support.
#
#
# Selected route: product
# Product Support Response:
#
# Hi Mike,
#
# Great question! Yes, you can absolutely export your project data to Excel, and I’m happy to walk you through the bulk export process step by step.
#
# **Step-by-Step Guide to Bulk Export:**
#
# 1. **Navigate to the Project Dashboard**
#    From your main workspace, click on the project you want to export.
#
# 2. **Open the Export Menu**
#    In the top-right corner of the project view, click the **“More”** (three-dot) menu, then select **“Export Data”**.
#
# 3. **Choose Your Export Format**
#    In the export dialog, select **“Excel (.xlsx)”** as your file format. You’ll also see options for CSV and PDF if needed.
#
# 4. **Select Data Scope**
#    Check the box labeled **“Include all tasks, subtasks, and comments”** to ensure a complete bulk export. You can also filter by date range or status if you only need a subset.
#
# 5. **Confirm and Download**
#    Click **“Export”** and the system will generate your file. Depending on project size, this may take a few seconds. Once ready, the download will start automatically.
#
# **Best Practices & Tips:**
# - **Use filters before exporting** to reduce file size and focus on relevant data (e.g., only tasks assigned to a specific team member).
# - **Schedule recurring exports** if you need regular snapshots. Go to **Settings > Automation > Scheduled Exports** to set this up.
# - **Check column mapping** – exported Excel files include standard fields like Task Name, Status, Assignee, Due Date, and Priority. Custom fields are also included automatically.
#
# **Related Features You Might Find Helpful:**
# - **Data Import** – If you ever need to bring data back in, check out our [Import Guide](https://docs.example.com/import) for supported formats.
# - **Reporting Dashboard** – For visual summaries without exporting, try the built-in Reports section under Analytics.
# - **API Access** – For advanced users, our [REST API](https://docs.example.com/api) allows programmatic data extraction.
#
# If you run into any issues or need help with a specific subset of data, just let me know. I’m here to help!
#
# Best regards,
# Your Product Specialist
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
